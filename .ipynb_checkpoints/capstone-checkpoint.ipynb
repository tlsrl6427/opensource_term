# %%
import os
import sys
import urllib.request

result=[]
keyword = "축구"
client_id = "mFVJrDtj4trdT2ermoVF"
client_secret = "hbpIY84KD3"
encText = urllib.parse.quote(keyword)
    
for i in range(1, 100, 10):
    
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText + f'&display=10&start={i}&sort=sim'# json 결과
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        result += [response_body.decode('utf-8')]
        print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Sat, 21 Aug 2021 16:16:18 +0900",
# "total": 3880910,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "뭉쳐야찬다2 :: 절실함으로 <b>축구</b>오디션에 참가한 카바디... ",
# "link": "https:\/\/blog.naver.com\/zamtangei?Redirect=Log&logNo=222470963066",
# "description": "이번에는 특히나 비인기 종목 선수들을 <b>축구</b> 오디션을 통해 선발할 것임을 예고해 더욱 기대를... 인기종목인 <b>축구</b>는 당연하게 받는 혜택들이 많고 올림픽 선수단 보면 가방부터 정장까지 제공되는 게 엄청... ",
# "bloggername": "따스한 햇살 그리고 가벼운 발걸음",
# "bloggerlink": "https://blog.naver.com/zamtangei",
# "postdate": "20210815"
#
# },
# {
# "title": "날 아침 바르셀로네타 해변ㅣ 여자 혼자 유럽<b>축구</b>여행 16일차①",
# "link": "https:\/\/blog.naver.com\/soccer_girl?Redirect=Log&logNo=222471365862",
# "description": "도시에서, <b>축구</b>도 보고, 정~~~~말로 좋았던 날씨 때문♥ 숙소에서 나오자 마자 적당한 바람과 햇볕과... 하는 <b>축구</b>도 이 곳 바르셀로나에서 마주치니까 넘 낭만적이야~♡ (드디어 바르셀로나 메시 유니폼 입은... ",
# "bloggername": ": 축구라면 지기 싫은 지윤이의 블로그",
# "bloggerlink": "https://blog.naver.com/soccer_girl",
# "postdate": "20210815"
#
# },
# {
# "title": "스포츠 경기 입장권 정리 - <b>축구</b> 직관 경기 BEST 11",
# "link": "https:\/\/blog.naver.com\/winz1?Redirect=Log&logNo=222453400852",
# "description": "프로농구, 프로야구, 프로배구 등 다양한 경기 입장권 중에서도 프로<b>축구</b> 입장권이 역시나 가장 많다. 나의 스포츠 라이프는 2006년 경남FC 창단과 함께 시작됐기 때문이다. 경남FC로 인해 킥오프한 <b>축구</b>... ",
# "bloggername": "스포츠에픽",
# "bloggerlink": "https://blog.naver.com/winz1",
# "postdate": "20210801"
#
# },
# {
# "title": "멕시코에 6:3충격패, <b>축구</b>는 11명이 하는 경기인데...",
# "link": "https:\/\/blog.naver.com\/ccead?Redirect=Log&logNo=222452950324",
# "description": "#김학범호 #올릭픽<b>축구</b> #도쿄올림픽<b>축구</b> #8강탈락 사진출처:아니뉴스24 개인적인 사담으로 시작하면, 예전 <b>축구</b>심판활동할때 생활체육<b>축구</b>심판(생활체육과통합되기전)들과 교류가 종종 있었답니다.... ",
# "bloggername": "제제날다",
# "bloggerlink": "https://blog.naver.com/ccead",
# "postdate": "20210801"
#
# },
# {
# "title": "컴퓨터 <b>축구</b>게임 1VS1 SOCCER",
# "link": "https:\/\/blog.naver.com\/hoiung8672?Redirect=Log&logNo=222398156585",
# "description": "원래 <b>축구</b>란 여러 사람들이 함께 필드 속에서 팀을 나누고 자신의 팀이 승리할 수 있도록 상대의 골대... 지금해볼 컴퓨터 <b>축구</b>게임은 화면 속 등장하게 된 두 명은 이제부터 경기를 진행하여 주시며 승리를... ",
# "bloggername": "게임보이",
# "bloggerlink": "https://blog.naver.com/hoiung8672",
# "postdate": "20210730"
#
# },
# {
# "title": "[방송리뷰] 슛돌이 3기 : 아이들의 <b>축구</b> 성장기!!!",
# "link": "https:\/\/blog.naver.com\/nongsae?Redirect=Log&logNo=222462938182",
# "description": "2021년 7월 ~ 8월 올림픽대표 <b>축구</b>를 열심히 봤다. 그 중에서 가장 눈여겨 본 선수는 이강인이었다. 2010년부터 10년 정도 한국 <b>축구</b> 뿐만 아니라 <b>축구</b> 자체를 거의 안봤다. 격투기와 주짓수만 열심히 봤다. 그러다가... ",
# "bloggername": "인생의 참맛(성주 믿음부동산)",
# "bloggerlink": "https://blog.naver.com/nongsae",
# "postdate": "20210809"
#
# },
# {
# "title": "도쿄올림픽 <b>축구</b> 일정 한국 멕시코 전적 선수명단",
# "link": "https:\/\/blog.naver.com\/dongi0508?Redirect=Log&logNo=222451030302",
# "description": "도쿄올림픽 <b>축구</b> 일정 한국 멕시코 전적 선수명단 드디어 7월31일 토요일. 한국시각으로 저녁 20시.... 위에 이미지는 대한민국 국가대표팀 도쿄올림픽 <b>축구</b> 일정이다. 8강에 오른 다른 팀들 보면 장난... ",
# "bloggername": "Der Sinn des Lebens",
# "bloggerlink": "https://blog.naver.com/dongi0508",
# "postdate": "20210730"
#
# },
# {
# "title": "HDC스포츠와 HDC현대EP 직원 가족이 함께한 뜻깊은 ‘<b>축구</b>... ",
# "link": "https:\/\/blog.naver.com\/iparkstory?Redirect=Log&logNo=222447158784",
# "description": "부산아이파크는 여름방학을 맞아 집중적으로 <b>축구</b>를 배우고 싶은 유소년과 가족을 위한 특강을 실시하고 있다. 미래의 <b>축구</b> 유망주를 육성하기 위해 5~13세 어린이 대상의 유소년 <b>축구</b>교실, ‘아이키즈’... ",
# "bloggername": "채널 HDC",
# "bloggerlink": "https://blog.naver.com/iparkstory",
# "postdate": "20210727"
#
# },
# {
# "title": "샘터찬물 276. <b>축구</b>",
# "link": "https:\/\/blog.naver.com\/wtp53?Redirect=Log&logNo=222441024737",
# "description": "아들이 친구로부터 급작스레 <b>축구</b> 경기 초대를 받았다. 수익금으로 아프리카 아이들을 원조하기 위해 개최되는 토너먼트 방식 경기라고 했다. 경기에 참가하는 다른 아이들은 어려서부터 유소년 <b>축구</b> 클럽에서... ",
# "bloggername": "키 큰 나무 숲",
# "bloggerlink": "https://blog.naver.com/wtp53",
# "postdate": "20210722"
#
# },
# {
# "title": "남북 모두에서 활동한 <b>축구</b>감독이 있다?",
# "link": "https:\/\/blog.naver.com\/gounikorea?Redirect=Log&logNo=222421901117",
# "description": "작성자 : 이영준 -1 남북 모두에서 활동한 <b>축구</b>감독이 있다? -2 여러분은 남북에서 모두 활동한 <b>축구</b>감독이 있다는 사실을 들어보신 적 있나요? -3 그 주인공은 바로 노르웨이 출신 예른 안데르센... ",
# "bloggername": "통일부 공식 블로그",
# "bloggerlink": "https://blog.naver.com/gounikorea",
# "postdate": "20210706"
#
# }
# ]
# }
#
# {
# "lastBuildDate": "Sat, 21 Aug 2021 16:16:18 +0900",
# "total": 3880910,
# "start": 11,
# "display": 10,
# "items": [
# {
# "title": "오~캐나다, 오마이갓 캐나다 여자<b>축구</b>",
# "link": "https:\/\/blog.naver.com\/yhkim444?Redirect=Log&logNo=222460136050",
# "description": "그런데 같은 시간대에 치러지는 또 다른 관심종목이 바로, 캐나다가 금메달을 놓고 강호 스워덴과 벌이는 여자<b>축구</b> 결승전 경기였습니다. 여자배구 경기가 끝나고 채널을 돌려 여자<b>축구</b> 결승전을 보기 시작한... ",
# "bloggername": "임금님 귀는 당나귀 귀",
# "bloggerlink": "https://blog.naver.com/yhkim444",
# "postdate": "20210807"
#
# },
# {
# "title": "한국 가나 <b>축구</b> 중계 방송 (대한민국)",
# "link": "https:\/\/blog.naver.com\/dydxodi333?Redirect=Log&logNo=222395070104",
# "description": "한국 가나 <b>축구</b> 중계 방송은 해주는 곳이 많으니 아래에서 골라 보시면 되겠습니다. http://m.site.naver.com/0OyOn 한국 가나 <b>축구</b> 중계 방송은 위에서 골라보시면 온라인 시청 가능하십니다. 그럼 <b>축구</b>에 대해서 조금... ",
# "bloggername": "당신의 리즈시절은",
# "bloggerlink": "https://blog.naver.com/dydxodi333",
# "postdate": "20210612"
#
# },
# {
# "title": "<b>축구</b>. 그 아름다운 스포츠 속에 숨겨진 과학기술 ①",
# "link": "https:\/\/blog.naver.com\/kipoworld2?Redirect=Log&logNo=222454377663",
# "description": "유로2020(유럽 대륙 <b>축구</b> 선수권대회), 코파아메리카(남미 <b>축구</b> 선수권대회)가 이탈리아와 아르헨티나의 우승으로 막을 내렸습니다. 전 세계적인 팬데믹 상황에서도 뜨겁게 치러졌죠. 오랜만의 국제적인... ",
# "bloggername": "특허청 공식 블로그",
# "bloggerlink": "https://blog.naver.com/kipoworld2",
# "postdate": "20210803"
#
# },
# {
# "title": "헬스 <b>축구</b> 할 때 언더해빗 무릎보호대",
# "link": "https:\/\/blog.naver.com\/2322033?Redirect=Log&logNo=222465841326",
# "description": "헬스 <b>축구</b> 등 과격한 운동에 꼭 필요한 제품 얼마전 올림픽 ~~ 경기 중에 가장 재미있게 본 건 아마도... 있더라고요 <b>축구</b> / 테니스 / 골프 / 배구 과격한 운동에는 역시나 ~~ 무릎보호대 필수 같아요 스포츠 활동... ",
# "bloggername": "초코빙수의 무한긍정에너지",
# "bloggerlink": "https://blog.naver.com/2322033",
# "postdate": "20210811"
#
# },
# {
# "title": "한국<b>축구</b> 전반의 흐름이 맘에 든다!",
# "link": "https:\/\/blog.naver.com\/ivanz?Redirect=Log&logNo=222450477164",
# "description": "도쿄올림픽까지 '한국<b>축구</b>는 일단 연령별 세계대회에 나서면 반드시 조별리그는 통과한다!'는 기분... 이것은 결국 따지고 보면 2001년 이후 대한<b>축구</b>협회가 파주 NFC 개장과 함께 역점 사업으로 시행한... ",
# "bloggername": "홍승범의 축구노트",
# "bloggerlink": "https://blog.naver.com/ivanz",
# "postdate": "20210730"
#
# },
# {
# "title": "청주<b>축구</b>교실은 뭐니뭐니해도 솔뫼<b>축구</b>클럽!",
# "link": "https:\/\/blog.naver.com\/qlskdhkfkt?Redirect=Log&logNo=222473246018",
# "description": "청주지역 대표<b>축구</b>교실로 자리매김한 솔뫼<b>축구</b>센터 <b>축구</b>클럽! 감사하게도 이미 청주지역의 많은 아이들이 수강생으로 등록되어 있는데요! 그 동안 저희만의 독자적인 커리큘럼과 탄탄한 시스템이 좋아서... ",
# "bloggername": "BEBETO 공식 블로그",
# "bloggerlink": "https://blog.naver.com/qlskdhkfkt",
# "postdate": "20210817"
#
# },
# {
# "title": "초등 집콕놀이 택배박스로 <b>축구</b>놀이 빈티나지만 재밌음",
# "link": "https:\/\/blog.naver.com\/dsjfh85?Redirect=Log&logNo=222477798264",
# "description": "선택해서 <b>축구</b>경기했어요 저 동그라미가 선수들인데 한번 그리면 변경할 수 가 없기에 팀은 한번씩 바꿔가면서 하면 되요 : ) 초등 집콕놀이 아빠와<b>축구</b> 게임 놀이 저희 아이는 1학년이에요 8살 ! 아이 수준에 딱... ",
# "bloggername": "민죠미 : 살며 사랑하며",
# "bloggerlink": "https://blog.naver.com/dsjfh85",
# "postdate": "20210820"
#
# },
# {
# "title": "2020 도쿄 올림픽 <b>축구</b> 대한민국 8강 멕시코 및 8강 대진표",
# "link": "https:\/\/blog.naver.com\/mr_mo_mo?Redirect=Log&logNo=222450273740",
# "description": "<b>축구</b>대표팀이 2020 도쿄올림픽에서 8강에 진출했습니다. 8강 상대는 북중미의 강호 멕시코 이번... 출처 : 한국<b>축구</b>협회 올림픽 <b>축구</b> 조편성 및 B조 최종결과 출처 : 네이버 출처 : 네이버 B조에... ",
# "bloggername": "미스터모모 컬렉션",
# "bloggerlink": "https://blog.naver.com/mr_mo_mo",
# "postdate": "20210729"
#
# },
# {
# "title": "저혈압은 남자 <b>축구</b> 보시고, 고혈압은 여자배구 보세요",
# "link": "https:\/\/blog.naver.com\/bulja200?Redirect=Log&logNo=222454379094",
# "description": "<b>축구</b>, 야구 배구 경기가 있던 날... 사실 저는 한국 <b>축구</b>를 신뢰하지 않습니다.... 뭐랄까, 우리 민족하고는 잘 안맞는 스포츠라고 단정지은 지가 오래거든요.... <b>축구</b>.... 아주 옛날...컬러티비가 없던 시절 부터... ",
# "bloggername": "부자와 빈자의 한 끗 차이 재테크",
# "bloggerlink": "https://blog.naver.com/bulja200",
# "postdate": "20210802"
#
# },
# {
# "title": "2020 도쿄올림픽 <b>축구</b>/야구 일정은?",
# "link": "https:\/\/blog.naver.com\/monnong?Redirect=Log&logNo=222423928746",
# "description": "(군면제 받자 ㅠㅠ) &quot; &quot; &quot; &quot; 포털사이트 어딜 찾아봐도 올림픽 <b>축구</b> 일정을 볼 수가 없어서 위키백과... 홈팀 일본, 프랑스, 멕시코 하지만 압권은 죽음의 D조 ㅋㅋ 브라질, 독일 그래도 올림픽 <b>축구</b>는 아무래도... ",
# "bloggername": "HOMIE DADDY'S PRIVATE PLACE",
# "bloggerlink": "https://blog.naver.com/monnong",
# "postdate": "20210708"
#
# }
# ]
# }
#
# {
# "lastBuildDate": "Sat, 21 Aug 2021 16:16:18 +0900",
# "total": 3880910,
# "start": 21,
# "display": 10,
# "items": [
# {
# "title": "15개월아기 <b>축구</b>신동 &amp; 주방놀이 삼매경 &amp; 물뱉기",
# "link": "https:\/\/blog.naver.com\/dony_zzang?Redirect=Log&logNo=222468601981",
# "description": "15개월아기 <b>축구</b>신동 &amp; 주방놀이 삼매경 &amp; 물뱉기 15개월아기 너무나 사랑스럽지만 그만큼 장꾸력이 상승... 나서는 <b>축구</b>선수처럼 뻥~ 차더니 이제는 수준급 드리블 실력까지.. <b>축구</b>신동 아닌가..?싶다 ㅋㅋㅋㅋ... ",
# "bloggername": "돈블리네 소소한 일상 ♡",
# "bloggerlink": "https://blog.naver.com/dony_zzang",
# "postdate": "20210813"
#
# },
# {
# "title": "<b>축구</b> 선수 피지컬 전문 - 용인 MST 트레이닝 센터",
# "link": "https:\/\/blog.naver.com\/sksist?Redirect=Log&logNo=222470455035",
# "description": "<b>축구</b> 선수들의 성장을 지원하는 피지컬 트레이닝 센터 &quot;MST 트레이닝 센터&quot; &quot;<b>축구</b> 선수들의 꿈을 지원하는 센터&quot; 국가대표 <b>축구</b>선수를 꿈꾸는 선수들!! 하지만 모두가 국가대표가 되는 건 아니기에 유소년... ",
# "bloggername": "MST 트레이닝센터",
# "bloggerlink": "https://blog.naver.com/sksist",
# "postdate": "20210815"
#
# },
# {
# "title": "부산성인<b>축구</b>교실",
# "link": "https:\/\/blog.naver.com\/welovebex?Redirect=Log&logNo=222423859267",
# "description": "#부산성인<b>축구</b>교실 #신규회원모집 #야외훈련 #부산경남울산최고환경 부산성인<b>축구</b>교실! 안녕하세요 부산성인<b>축구</b>교실 입니다. 참,, 뭐가 이렇게 바쁜지 ㅠㅠ 사진과 영상은 한가득은데 ,, 포스팅을 지속적으로... ",
# "bloggername": "축구지도자 킹콩쌤",
# "bloggerlink": "https://blog.naver.com/welovebex",
# "postdate": "20210707"
#
# },
# {
# "title": "하..너넨 '<b>축구</b>'같은거 보지마라",
# "link": "https:\/\/blog.naver.com\/dlvmshtm13?Redirect=Log&logNo=222430222000",
# "description": "이상하게도 우승 당일엔 아무렇지도 않아서 어라 나..어쩌면 <b>축구</b>와 절.교 가 가능해졌을지도? 라는 생각을 했었는데 이런 Sibal 시간이 지날수록 여운이 장난이 아니다. 리오넬 메시라는 <b>축구</b>선수를 좋아하기... ",
# "bloggername": "J-HOUSE",
# "bloggerlink": "https://blog.naver.com/dlvmshtm13",
# "postdate": "20210713"
#
# },
# {
# "title": "<b>축구</b>학원 자세하게 알아보는 방법!",
# "link": "https:\/\/blog.naver.com\/hissong0677?Redirect=Log&logNo=222439753474",
# "description": "흔히 접할 수 있고 재밌게 즐길 수 있는 <b>축구</b>에 대해 많이 알아보고 계십니다. 요즘 아이들이 쉽게 배울 수 있는 <b>축구</b>학원이 정말 많아지고 있죠. 다양한 프로그램과 장소 등 학원마다 특징과 진행하고 있는... ",
# "bloggername": "Blooming Mellow",
# "bloggerlink": "https://blog.naver.com/hissong0677",
# "postdate": "20210721"
#
# },
# {
# "title": "이탈리아 <b>축구</b>와 영화",
# "link": "https:\/\/blog.naver.com\/hans427?Redirect=Log&logNo=222430345029",
# "description": "선수 때도 빠르고, 약은 여우였는데, <b>축구</b>계의 마키아벨리 같다. 유럽 국가들이 대부분 그렇듯 이탈리아도 <b>축구</b>에 '미친' 나라다. 어떨 때는 그런 문화가 과도해, 부담스럽기도 했다. 자본주의의 압축된 세상... ",
# "bloggername": "영화, 그림 속을 걷고 싶다",
# "bloggerlink": "https://blog.naver.com/hans427",
# "postdate": "20210713"
#
# },
# {
# "title": "유로 결승전으로 근무시간까지 변경! <b>축구</b>에 진심인 영국인들",
# "link": "https:\/\/blog.naver.com\/red_thwjd?Redirect=Log&logNo=222427331397",
# "description": "트래팔가 광장에 모인 영국 <b>축구</b>팬들 요즘 유로 2020으로 영국은 완전 코로나 종식 + 잔치 분위기네요! 작년에 못한 경기를 지금 해서 아직 2020 타이틀을 가지고.. 저는 원래 <b>축구</b>에 쪼~끔 관심... ",
# "bloggername": "Create your dream life",
# "bloggerlink": "https://blog.naver.com/red_thwjd",
# "postdate": "20210711"
#
# },
# {
# "title": "올림픽 <b>축구</b> 한국 VS 멕시코 8강 결과 예상",
# "link": "https:\/\/blog.naver.com\/peterfine?Redirect=Log&logNo=222451174675",
# "description": "올림픽 <b>축구</b> 한국 VS 멕시코 8강 결과 예상 올림픽 <b>축구</b> 대표팀이 약체 뉴질랜드에 불의의 일격을 당한 후 루마니아와 온두라스를 차례로 대파하고 조 1위로 8강에 올랐다. 멕시코와는 역대 전전에서 A대표님의... ",
# "bloggername": "사색하는 자유(Truth will set you free)",
# "bloggerlink": "https://blog.naver.com/peterfine",
# "postdate": "20210730"
#
# },
# {
# "title": "[채용공고] SPOTV 해외<b>축구</b> 해설위원 선발 오디션 개최",
# "link": "https:\/\/blog.naver.com\/spotv_sports?Redirect=Log&logNo=222466996733",
# "description": "해외<b>축구</b> 해설위원 오디션 안내 ■ 문의사항은 메일(*******@*****.***)로 남겨주시기 바랍니다. ※ 입사지원 서류에 허위사실이 발견될 경우, 채용 확정 이후라도 채용이 취소될 수 있습니다. 해외<b>축구</b>... ",
# "bloggername": "SPOTV",
# "bloggerlink": "https://blog.naver.com/spotv_sports",
# "postdate": "20210812"
#
# },
# {
# "title": "두뇌회전과 체력이 필요한 <b>축구</b>선수들이 파스타를 먹는 이유?",
# "link": "https:\/\/blog.naver.com\/kofmia?Redirect=Log&logNo=222414051286",
# "description": "그런데 체중과 체력 관리가 필수인 <b>축구</b>선수, 스케이팅 선수 등 다양한 장르의 운동선수들은 운동 전 파스타를 즐겨 먹는다고 하는데요. <b>축구</b>선수를 비롯해 영양과 식단관리가 필수인 운동선수들이... ",
# "bloggername": "한국제분협회 밀교수의 밀가루 이야기",
# "bloggerlink": "https://blog.naver.com/kofmia",
# "postdate": "20210629"
#
# }
# ]
# }
# {
# "lastBuildDate": "Sat, 21 Aug 2021 16:16:18 +0900",
# "total": 3880910,
# "start": 31,
# "display": 10,
# "items": [
# {
# "title": "군산 <b>축구</b>의 전설, 대한민국 <b>축구</b> 영웅 채금석 전시회",
# "link": "https:\/\/blog.naver.com\/gunsanpr?Redirect=Log&logNo=222441263706",
# "description": "군산 <b>축구</b>의 전설, 대한민국 <b>축구</b> 영웅 채금석 전시회 장맛비 내리는 7월 어느 날 아내와 함께 군산 나들이를 나섭니다. 많은 비가 내리는 전군 산업도로를 타고 가는 길이었는데요. 눈이 오나, 비가 오나 안전... ",
# "bloggername": "군산시 공식 블로그",
# "bloggerlink": "https://blog.naver.com/gunsanpr",
# "postdate": "20210728"
#
# },
# {
# "title": "한국 온두라스 <b>축구</b> 중계 (도쿄 올림픽) 보는 곳",
# "link": "https:\/\/blog.naver.com\/dydxodi333?Redirect=Log&logNo=222448350755",
# "description": "B조 최약체라고 불리우던 팀 뉴질랜드에게 패배를 당한 대한민국 <b>축구</b> 대표팀이 비교적 강팀인... 8강으로 가느냐 못가느냐 가장 중요한 경기인데요, 한국 온두라스 <b>축구</b> 중계는 아래 참고하시면 PC 및... ",
# "bloggername": "당신의 리즈시절은",
# "bloggerlink": "https://blog.naver.com/dydxodi333",
# "postdate": "20210728"
#
# },
# {
# "title": "2020 도쿄 올림픽 <b>축구</b> 국가대표팀 엔트리 및 예선경기 일정",
# "link": "https:\/\/blog.naver.com\/mr_mo_mo?Redirect=Log&logNo=222441074724",
# "description": "경기는 어제부터 시작됐고, 오늘 대한민국 <b>축구</b>대표팀의 예선 첫경기가 열릴 예정입니다. 출처 : 대한<b>축구</b>협회 올림픽 대표팀 명단 출처 : 대한<b>축구</b>협회 출처 : 대한<b>축구</b>협회 공격수 - 권창훈, 송민규, 엄원상... ",
# "bloggername": "미스터모모 컬렉션",
# "bloggerlink": "https://blog.naver.com/mr_mo_mo",
# "postdate": "20210722"
#
# },
# {
# "title": "성인<b>축구</b>교실, 레슨 알아보시는 분들 꼭 보세요~",
# "link": "https:\/\/blog.naver.com\/qlskdhkfk2228?Redirect=Log&logNo=222442266492",
# "description": "한국 <b>축구</b>! 온 국민의 관심도 뜨거운 스포츠 종목 중 하나인데요. 대한민국 남자라면, 어릴 때부터 성인이 될 때까지 군대에서도 빠질 수 없는 것이 바로 <b>축구</b> 아니겠습니까 ㅎㅎ <b>축구</b>는 개인 플레이가... ",
# "bloggername": "스토래지풋살",
# "bloggerlink": "https://blog.naver.com/qlskdhkfk2228",
# "postdate": "20210723"
#
# },
# {
# "title": "SBS 골때리는 그녀들 출연진 팀 정보 아이린 한혜진 <b>축구</b>... ",
# "link": "https:\/\/blog.naver.com\/chesungmin?Redirect=Log&logNo=222400396664",
# "description": "SBS 골때리는 그녀들 출연진 팀 정보 모델 아이린 한혜진 <b>축구</b> 실력은!? 오늘 재미있는 예능이 새로... 장난으로 하는 것이 아닌 제대로 <b>축구</b>화를 신고 교육을 받고 훈련을 한후에 하는 여자 풋살 <b>축구</b> 예능이... ",
# "bloggername": "오늘의 추천아이템",
# "bloggerlink": "https://blog.naver.com/chesungmin",
# "postdate": "20210616"
#
# },
# {
# "title": "로베르트 레반도프스키, '2021 독일 올해의 <b>축구</b> 선수' 선정",
# "link": "https:\/\/blog.naver.com\/mark_420?Redirect=Log&logNo=222446332344",
# "description": "바이에른 공격수의 2년 연속 수상 로베르트 레반도프스키, '2021년 독일 올해의 <b>축구</b> 선수' 선정 2020년과 마찬가지로 올해의 <b>축구</b> 선수 투표에서 로베르트 레반도프스키의 선정 외엔 다른 결과가 나오지... ",
# "bloggername": "FC Bayern",
# "bloggerlink": "https://blog.naver.com/mark_420",
# "postdate": "20210726"
#
# },
# {
# "title": "오늘의스코어 통해 라리가 해외<b>축구</b>경기일정 완벽 체크!",
# "link": "https:\/\/blog.naver.com\/doek11?Redirect=Log&logNo=222459458367",
# "description": "남자 <b>축구</b>는 비록 본선 토너먼트 첫 경기에서 멕시코에게 6 대 3 패를 당하고 말았지만, 예선에서는 B조... 사실 처음에는 메이저리그 무료 그래픽 중계 기능을 지원한다길래 받았다가, 농구와 <b>축구</b>까지 폭넓게... ",
# "bloggername": "네오필 블로그",
# "bloggerlink": "https://blog.naver.com/doek11",
# "postdate": "20210806"
#
# },
# {
# "title": "오늘의스코어 프리미어리그 해외<b>축구</b>경기일정 손흥민 선수... ",
# "link": "https:\/\/blog.naver.com\/ha_tak?Redirect=Log&logNo=222473065742",
# "description": "이번에 소개할 내용은 오늘의스코어를 이용하여 프리미어리그 및 해외<b>축구</b>경기일정을 확인하고 손흥민... 특히 오늘의스코어는 그래픽 중계로 유명했던 앱이며, <b>축구</b>, 야구, 농구 등 다양한 경기들을 보여주는... ",
# "bloggername": "리뷰빌런 하텍",
# "bloggerlink": "https://blog.naver.com/ha_tak",
# "postdate": "20210817"
#
# },
# {
# "title": "도쿄올림픽 <b>축구</b> 일정 조별순위 8강전 한국 멕시코 <b>축구</b> 중계",
# "link": "https:\/\/blog.naver.com\/yes4500?Redirect=Log&logNo=222415258589",
# "description": "●도쿄올림픽 <b>축구</b> 일정 및 조별 순위 ●올림픽 <b>축구</b> 대표팀 8강전 ●한국 vs 멕시코 7월 31일(토) 20시 00분 ●TV 중계방송 KBS (캐스터 남현종 / 해설위원 : 조원희) MBC (캐스터 김정근 /해설위원 : 안정환) SBS... ",
# "bloggername": "브로찌",
# "bloggerlink": "https://blog.naver.com/yes4500",
# "postdate": "20210630"
#
# },
# {
# "title": "럭비와 미식<b>축구</b> 차이점은? 럭비 국가대표팀 98년 만에 올림픽... ",
# "link": "https:\/\/blog.naver.com\/hackersingang?Redirect=Log&logNo=222473632525",
# "description": "그래서 오늘은 2020 도쿄올림픽 속 대한민국의 럭비 국가대표의 첫 올림픽 현장과 럭비 미식<b>축구</b>의... :) 다음으로는 많은 사람들이 헷갈려 하시는 럭비 와 미식<b>축구</b>의 차이점에 대해서 알려드릴게요! 럭비... ",
# "bloggername": "해커스인강 공식 블로그",
# "bloggerlink": "https://blog.naver.com/hackersingang",
# "postdate": "20210817"
#
# }
# ]
# }
#
# {
# "lastBuildDate": "Sat, 21 Aug 2021 16:16:18 +0900",
# "total": 3880910,
# "start": 41,
# "display": 10,
# "items": [
# {
# "title": "<b>축구</b>안경 도수넣기 / 운동용고글 착용하기",
# "link": "https:\/\/blog.naver.com\/wjdgml4188?Redirect=Log&logNo=222451297821",
# "description": "<b>축구</b>를 할때 사용할 예정이기에 운동용 고글을 픽해 주셨어요. 코에는 두툼한 실리콘 패드가 장착되어 압박시 무리가 덜 가도록 하였으며 끈끈한 실리콘 소재로 흘러내리을 줄이는 효과가 있어요. 측면에도... ",
# "bloggername": "안경렌즈 전문점",
# "bloggerlink": "https://blog.naver.com/wjdgml4188",
# "postdate": "20210730"
#
# },
# {
# "title": "도쿄올림픽 <b>축구</b> 8강 경기 일정 &amp; 대진표_ 8강전(vs. 멕시코)",
# "link": "https:\/\/blog.naver.com\/spring0915?Redirect=Log&logNo=222450423832",
# "description": "남자<b>축구</b> 8강 일정 대한민국 vs 멕시코 07.31(토) 20:00 브라질 vs 이집트 07. 31(토) 19:00 일본 vs 뉴질랜드 07.31(토) 18:00 스페인 vs 코트디부아르 07.31(토) 17:00 도쿄올림픽 남자<b>축구</b> 조별 리그 1차전 vs 뉴질랜드... ",
# "bloggername": "엄마여행작가 다이어리",
# "bloggerlink": "https://blog.naver.com/spring0915",
# "postdate": "20210730"
#
# },
# {
# "title": "FIFA,국제<b>축구</b>연맹 새로운 변화 시작!?",
# "link": "https:\/\/blog.naver.com\/rlaxodhkswkd?Redirect=Log&logNo=222437020213",
# "description": "FIFA 국제<b>축구</b>연맹 새로운 변화 안녕하세요 DOING 입니다. 이번 시간에는 FIFA에서 발표한 새로운 변화... 통해 <b>축구</b>의 재미를 더하겠다고 전했습니다. TIME 가장 먼저는 시간입니다. 현재 <b>축구</b>는 다른 스포츠와... ",
# "bloggername": "DOING BLOG",
# "bloggerlink": "https://blog.naver.com/rlaxodhkswkd",
# "postdate": "20210719"
#
# },
# {
# "title": "도쿄올림픽 <b>축구</b>대표팀 돌아보기 - 떠오르는 의문들 자문자답",
# "link": "https:\/\/blog.naver.com\/tentama?Redirect=Log&logNo=222460960946",
# "description": "메달을 기대했던 도쿄 올림픽 대한민국 <b>축구</b>대표팀은 장밋빛 기대와는 달리 8강에서 탈락하며 쓸쓸하게... 전체적으로 <b>축구</b> 협회의 행정이 예전 같지 않다는 느낌을 많이 받습니다. 정보력에서나 선수 선발에... ",
# "bloggername": "녹색 도화지 위의 수채화",
# "bloggerlink": "https://blog.naver.com/tentama",
# "postdate": "20210807"
#
# },
# {
# "title": "미군용기 랜딩기어에 끼어 숨진 아프칸 유소년 국가대표 <b>축구</b> 선수",
# "link": "https:\/\/blog.naver.com\/peace_2000?Redirect=Log&logNo=222476148769",
# "description": "그들 중 한사람의 신원이 밝혀졌는데 아프가니스탄 유소년 국가대표 <b>축구</b> 선수 자키 안바리라는 소년입니다. 그의 신체 일부가 비행기 랜딩 기어에 끼인 채... ",
# "bloggername": "관심가는 대로",
# "bloggerlink": "https://blog.naver.com/peace_2000",
# "postdate": "20210819"
#
# },
# {
# "title": "2020 도쿄 올림픽 남자<b>축구</b> 준결승 대진표 일본 스페인 맞대결",
# "link": "https:\/\/blog.naver.com\/mr_mo_mo?Redirect=Log&logNo=222454833238",
# "description": "2020 도쿄올림픽 남자 <b>축구</b> 4강 대진표가 결정되었습니다. 비록 대한민국 올림픽 <b>축구</b>대표팀은 7월 31일 토요일 멕시코와의 8강전에서 3-6으로 패배 아쉽게 8강에서 탈락했습니다. 하지만 2012 런던 2016... ",
# "bloggername": "미스터모모 컬렉션",
# "bloggerlink": "https://blog.naver.com/mr_mo_mo",
# "postdate": "20210802"
#
# },
# {
# "title": "제32회 도쿄올림픽  <b>축구</b>경기 대한민국: 온두라스^*^",
# "link": "https:\/\/blog.naver.com\/ksn1665?Redirect=Log&logNo=222449762286",
# "description": "하더군요 <b>축구</b> 경기. 야 구경기 티브이 관전엔 통닭이 최고지요 울 큰아들 퇴근하고 분가해서 오랜만에... 든든합니다 <b>축구</b> 승전보만큼이나 아이구 멋진 내 아들들!!! 어제 오후 7시 이스라엘과 요코하마... ",
# "bloggername": "♪ Home sweet Home ☆",
# "bloggerlink": "https://blog.naver.com/ksn1665",
# "postdate": "20210730"
#
# },
# {
# "title": "먹방 찍다가 끝나버린 올림픽 <b>축구</b>",
# "link": "https:\/\/blog.naver.com\/yousy1009?Redirect=Log&logNo=222454486461",
# "description": "올림픽 <b>축구</b>ㅋㅋㅋㅋ 새우귀신이 있다보니 활새우가 나왔다니 바로 시켰지요 이른감이 있는데오 벌써... <b>축구</b>하는날이라 치킨은 미리미리 시켜야한다는 소리에 2시간전에 시켰는데 생각보다 빨리 도착! 그 덕에... ",
# "bloggername": "알쏭달쏭~",
# "bloggerlink": "https://blog.naver.com/yousy1009",
# "postdate": "20210802"
#
# },
# {
# "title": "[제품리뷰]마스터삭스 브이존 기능성 하프삭스 - 기능성 <b>축구</b> 양말",
# "link": "https:\/\/blog.naver.com\/yonghwi1?Redirect=Log&logNo=222470022517",
# "description": "[제품리뷰]마스터삭스 브이존 기능성 하프삭스 - 기능성 <b>축구</b> 양말 오랜만에 제품을 제공받아서 리뷰를 해보려고 한다. 오늘 소개할 제품은 마스터삭스라고 하는 기능성 <b>축구</b> 양말이다. 요새 정말 양말의... ",
# "bloggername": "축구피지컬코치 안정혁",
# "bloggerlink": "https://blog.naver.com/yonghwi1",
# "postdate": "20210814"
#
# },
# {
# "title": "인천주니어<b>축구</b>클럽-유소년<b>축구</b>레슨",
# "link": "https:\/\/blog.naver.com\/kkjkkj2000?Redirect=Log&logNo=222412803425",
# "description": "주니어<b>축구</b>클럽에 도움이 될까 싶어 오늘도 글을 올리네요!! 인천주니어<b>축구</b>클럽에서 유소년부터 시작해서 성인<b>축구</b>클럽 까지 미래를 책임질 <b>축구</b> 꿈나무를 모집하고 있습니다. 블로그 한지 어느덧 10년 가까이... ",
# "bloggername": "나무(木) 처럼.....^^ Wood story!!",
# "bloggerlink": "https://blog.naver.com/kkjkkj2000",
# "postdate": "20210628"
#
# }
# ]
# }
#
# {
# "lastBuildDate": "Sat, 21 Aug 2021 16:16:19 +0900",
# "total": 3880910,
# "start": 51,
# "display": 10,
# "items": [
# {
# "title": "인도네시아는 왜 <b>축구</b>를 못할까?",
# "link": "https:\/\/blog.naver.com\/hurkle97?Redirect=Log&logNo=222466488680",
# "description": "찜통더위에도 <b>축구</b>할 정도로 다들 <b>축구</b>를 좋아하고 <b>축구</b>도 잘하는 인도네시아 친구들. 시간만 나면 스마트폰으로 잉글랜드 프리미어리그 보고 기숙사, 자취방에도 <b>축구</b>화, <b>축구</b>공이 가득하고 ~ 자기들끼리... ",
# "bloggername": "이삭줍기",
# "bloggerlink": "https://blog.naver.com/hurkle97",
# "postdate": "20210812"
#
# },
# {
# "title": "주성치 감독의 '소림<b>축구</b>' (2001)",
# "link": "https:\/\/blog.naver.com\/banaly?Redirect=Log&logNo=222432573406",
# "description": "이 '소림<b>축구</b>와 '쿵푸허슬' 일 것이다. 이전 작품들에 비해서 '소림<b>축구</b>'가 폭력성이 두드러진다고 생각한다. 그런데 이후 작품인 '쿵푸허슬'은 폭력성에 잔인함도 더해진 것 같다. 이후 주성치의 작품은... ",
# "bloggername": "방바닥 블로그",
# "bloggerlink": "https://blog.naver.com/banaly",
# "postdate": "20210716"
#
# },
# {
# "title": "유로 2020을 보면서 포르투갈 <b>축구</b>팀 생각",
# "link": "https:\/\/blog.naver.com\/byleekim2?Redirect=Log&logNo=222416703587",
# "description": "유로 <b>축구</b>도 월드컵처럼 4년마다 1번씩 하는거야. 하나만 알고 둘은 모르는 나 며칠 전에 영국과 독일... 포르투갈 <b>축구</b> 유로 2020에서 독일전에서 자책골을 2개나 넣으면서 산화한 포르투갈 <b>축구</b>팀! 유로... ",
# "bloggername": "올리브와 레몬나무",
# "bloggerlink": "https://blog.naver.com/byleekim2",
# "postdate": "20210701"
#
# },
# {
# "title": "브라질에서 <b>축구</b>수업.ㅋ",
# "link": "https:\/\/blog.naver.com\/cos2x?Redirect=Log&logNo=222442016283",
# "description": "ㅋㅋㅋ) <b>축구</b> 수업을 시작했습니다. 아기때부터 소근육 발달이 빠르고 남달랐던 뒹굴이인데, 그에 비해 대근육 발달은 참 더뎠습니다. 브라질이라 그런지 우리나라도 그런지는 모르겠지만, 이곳은 <b>축구</b> 수업이... ",
# "bloggername": "꿈꾸는 베짱이",
# "bloggerlink": "https://blog.naver.com/cos2x",
# "postdate": "20210723"
#
# },
# {
# "title": "신시아 P4U <b>축구</b> 1년",
# "link": "https:\/\/blog.naver.com\/pinktao?Redirect=Log&logNo=222467648130",
# "description": "작년 6월말에 얼떨결에 체험수업후 7월부터 쭈욱 다니고 있는 <b>축구</b>교실 사실 아들은 아주많이... 그때는 차량을 이용할것도 같다 ㅎㅎ #p4u<b>축구</b>교실 #신시아p4u #수요일엔<b>축구</b>오빠 #어느새일년 #일곱살<b>축구</b>",
# "bloggername": "하루하루가 반짝반짝 빛난다!",
# "bloggerlink": "https://blog.naver.com/pinktao",
# "postdate": "20210812"
#
# },
# {
# "title": "성장기 <b>축구</b> 선수 영양 가이드라인",
# "link": "https:\/\/blog.naver.com\/iamprotein?Redirect=Log&logNo=222448388579",
# "description": "[출처]K LEAGUE (사)한국프로<b>축구</b>연맹 유소년 <b>축구</b> 선수 의 영양 관리 1.유소년 <b>축구</b> 선수의 신체발달 신신심장이 성장하는 시기에 충분이 영양 섭취 하는 것이 필요합니다. 신장이 성장 하는 동안에 식사량이... ",
# "bloggername": "스포츠영양-아이엠프로틴",
# "bloggerlink": "https://blog.naver.com/iamprotein",
# "postdate": "20210728"
#
# },
# {
# "title": "도쿄 올림픽 <b>축구</b> 일정 _ 토요일 8강 토너먼트 대진표",
# "link": "https:\/\/blog.naver.com\/hapymee?Redirect=Log&logNo=222449307180",
# "description": "2020 도쿄 올림픽 <b>축구</b> 일정 8강 토너먼트 대진표 주말에 어디가지말고 (어차피 안나감) 집에서 올림픽 시청하기 좋은 스케쥴! 2020도쿄올림픽 <b>축구</b>... 무슨일이죠? 어제(2021년7월28일) 16강전을 보면서 6:0... ",
# "bloggername": "HanssTV",
# "bloggerlink": "https://blog.naver.com/hapymee",
# "postdate": "20210729"
#
# },
# {
# "title": "열린 생활 체육공간, 용정 <b>축구</b>공원을 소개합니다.",
# "link": "https:\/\/blog.naver.com\/cjcityblog?Redirect=Log&logNo=222416180825",
# "description": "요즘 도쿄 올림픽 <b>축구</b> 준비로 <b>축구</b> 열기가 다시 타오르고 있답니다. 제가 <b>축구</b> 이야기를 꺼낸 이유는, 다름 아닌 이곳을 소개해 드리려고 합니다. 청주시 상당구 용정동에 위치한 용정 <b>축구</b>공원은 365일... ",
# "bloggername": "청주시청 공식 블로그",
# "bloggerlink": "https://blog.naver.com/cjcityblog",
# "postdate": "20210710"
#
# },
# {
# "title": "남자<b>축구</b> 결승전 스페인 브라질 일본 4위 여자<b>축구</b> 캐나다... ",
# "link": "https:\/\/blog.naver.com\/mr_mo_mo?Redirect=Log&logNo=222460644736",
# "description": "메달 획득을 목표로 했던 대한민국 남자<b>축구</b>대표팀이 아쉽게 8강에서 멕시코에 탈락했던 남자 <b>축구</b> 일본 또한 4강에 진출했지만 역시 멕시코에서 1-3으로 패하며 또 4위에 머물렸는데요. 출처 : FIFA 도쿄... ",
# "bloggername": "미스터모모 컬렉션",
# "bloggerlink": "https://blog.naver.com/mr_mo_mo",
# "postdate": "20210807"
#
# },
# {
# "title": "<b>축구</b>하다가 진짜로 무릎 나간 30대 여성",
# "link": "https:\/\/blog.naver.com\/entercode?Redirect=Log&logNo=222468137641",
# "description": "<b>축구</b>를 하다가 무릎이 분리되었다가 돌아왔단다. 십자인대가 파열되지 않고 오히려 경골에 붙은 뼈가... 군대에서 <b>축구</b>하다가 십자인대 파열되어 의가사제대하는 케이스라고. 좀 기다려봤다가 뼈가 붙지 않으면... ",
# "bloggername": "사람이야기 医句话",
# "bloggerlink": "https://blog.naver.com/entercode",
# "postdate": "20210813"
#
# }
# ]
# }
# {
# "lastBuildDate": "Sat, 21 Aug 2021 16:16:19 +0900",
# "total": 3880910,
# "start": 61,
# "display": 10,
# "items": [
# {
# "title": "[여자<b>축구</b>/풋살/골때리는그녀들]<b>축구</b> 입문기",
# "link": "https:\/\/blog.naver.com\/astralberry?Redirect=Log&logNo=222436569972",
# "description": "정말 <b>축구</b> 위주로 돌아가는 삶... 나는 거의 요가,피티,조깅같이 개인 스포츠만 했는데 골때녀를 보고 팀스포츠의 매력에 빠졌다. 여럿이서 공동의 목표를 향해 함께 돌진하는 모습이 짜릿했다. 자연스레 <b>축구</b>... ",
# "bloggername": "Everywhere but nowhere",
# "bloggerlink": "https://blog.naver.com/astralberry",
# "postdate": "20210719"
#
# },
# {
# "title": "<b>축구</b> 여자배구 뭘봐야할지몰라서 다봄",
# "link": "https:\/\/blog.naver.com\/lovelymooong?Redirect=Log&logNo=222452626769",
# "description": "<b>축구</b> 여자배구 뭘봐야할지몰라서 다봄 오늘은 <b>축구</b>, 여자배구, 야구 시간이 다 겹치는 대박의날. 나는 축덕이니 <b>축구</b>보고, 남은시간 여자배구 봤다. <b>축구</b> 보는 내내 ㅠㅠㅠ 아빠는 sbs 엄마랑 나는 mbc 해설은... ",
# "bloggername": "몽블리",
# "bloggerlink": "https://blog.naver.com/lovelymooong",
# "postdate": "20210731"
#
# },
# {
# "title": "&quot;<b>축구</b>! 우리도 할 수 있어&quot; ─ 우아하고 호쾌한! SBS 《골... ",
# "link": "https:\/\/blog.naver.com\/minumworld?Redirect=Log&logNo=222445938187",
# "description": "<b>축구</b>! 우리도 할 수 있어! 진정성 200%! <b>축구</b>에 진심인 그녀들과 대한민국 레전드 태극전사들이 함께 만들어가는 건강한 소모임 탄생! Goal 때리게 재밌고! Goal 때리게 쫄깃한! 여자 <b>축구</b>의 르네상스! SBS 《골... ",
# "bloggername": "민음사 블로그",
# "bloggerlink": "https://blog.naver.com/minumworld",
# "postdate": "20210726"
#
# },
# {
# "title": "클라스크 2인 보드게임 코시국 집에서 즐기는 <b>축구</b>게임 강력... ",
# "link": "https:\/\/blog.naver.com\/kingeyes79?Redirect=Log&logNo=222449642339",
# "description": "어른 아이 할 것 없이 즐겁게 할 수 있는 2인 보드게임 <b>축구</b>게임 추천드리고자 해요. 클라스크 2인... 올림픽 <b>축구</b>게임 보며 자기들도 게임한다더니 자기 전까지 하더라고요. 아침에도 눈 떠보니 자기들끼리... ",
# "bloggername": "키매 ♥ 캠핑.여행.리뷰 로그",
# "bloggerlink": "https://blog.naver.com/kingeyes79",
# "postdate": "20210730"
#
# },
# {
# "title": "베트남의 불토는 도쿄 올림픽과 함께(여자배구,야구,<b>축구</b>... ",
# "link": "https:\/\/blog.naver.com\/champ76?Redirect=Log&logNo=222452735655",
# "description": "야구 <b>축구</b>가 하는 것을 알고는 야구 <b>축구</b>를 보다가 다시 배구를 봤다 https://m.blog.naver.com/champ76/222295574008 여자 배구 한일전 승리!!!! 손에 땀을 쥐던 경기 마지막 승리하는 모습은 하필 딱 그때... ",
# "bloggername": "추억은 방울방울",
# "bloggerlink": "https://blog.naver.com/champ76",
# "postdate": "20210801"
#
# },
# {
# "title": "부천 야간<b>축구</b>경기 스트레스 해소 짱",
# "link": "https:\/\/blog.naver.com\/rlfem1wls?Redirect=Log&logNo=222410622307",
# "description": "안녕하세요~~ 힐링터치 건강운동센터 입니다~ ^^ 금일은 부천 야간<b>축구</b>경기 스트레스 해소 짱이란 주제로 <b>축구</b>클럽 이야기를 이어 가도록 하겠습니다. 야간<b>축구</b>클럽은 두군데서 뛰고 있는데 이번에 뛰는... ",
# "bloggername": "힐링터치 건강운동센터",
# "bloggerlink": "https://blog.naver.com/rlfem1wls",
# "postdate": "20210707"
#
# },
# {
# "title": "'대한민국 <b>축구</b> 역사박물관(가칭)' 유물 기증식",
# "link": "https:\/\/blog.naver.com\/fastcheonan?Redirect=Log&logNo=222431155290",
# "description": "천안시 출신 대한<b>축구</b>협회 박경훈 전무이사가 유물 112점을 기증했습니다! 안녕하세요. 천안시입니다. 천안시는 2019년 8월 1일, 대한<b>축구</b>협회와 '대한민국 <b>축구</b>종합센터 건립사업' 협약을 체결한 후, 현재... ",
# "bloggername": "새로운 천안 행복한 시민",
# "bloggerlink": "https://blog.naver.com/fastcheonan",
# "postdate": "20210715"
#
# },
# {
# "title": "이천<b>축구</b>]이천유나이티드 <b>축구</b> 클럽",
# "link": "https:\/\/blog.naver.com\/gmlwn2149?Redirect=Log&logNo=222464311241",
# "description": "#이천<b>축구</b> #<b>축구</b>맛집 #이천유나이티드풋볼클럽 #이천유나이티드FC #이천유나이티드 #이천엘리트<b>축구</b> #이천<b>축구</b>교실 #이천<b>축구</b>취미반 #이천<b>축구</b>개인레슨 #이천<b>축구</b>그룹레슨 #이천유나이티드U10... ",
# "bloggername": "손블리의 바람난 주방",
# "bloggerlink": "https://blog.naver.com/gmlwn2149",
# "postdate": "20210810"
#
# },
# {
# "title": "무더위 피해 <b>축구</b>책여행 &lt;나 홀로 <b>축구</b> 여행&gt; &amp; &lt;사랑한다 내... ",
# "link": "https:\/\/blog.naver.com\/winz1?Redirect=Log&logNo=222458286614",
# "description": "휴가를 즐기는 방법 중 한 가지는 <b>축구</b>책여행이다. 두 권의 책 &lt;나 홀로 <b>축구</b> 여행&gt;과 &lt;사랑한다 내 꿈아&gt;는 마음 편하게 읽기 좋았다. 원래 해외여행을 자주 가는 편이 아니었지만 타의로 못 가는 상황에... ",
# "bloggername": "스포츠에픽",
# "bloggerlink": "https://blog.naver.com/winz1",
# "postdate": "20210805"
#
# },
# {
# "title": "7월 28일. 올림픽 <b>축구</b> 8강, 펜싱 사브르 단체전 금상",
# "link": "https:\/\/blog.naver.com\/diva440?Redirect=Log&logNo=222449090425",
# "description": "7/28수 올림픽 <b>축구</b> 8강, 펜싱 사브르 단체전 금상 원래 스포츠를 그다지 즐겨 보는 편도 아니고, 챙겨... 오늘 <b>축구</b>는 온두라스와의 경기였다. 초반 패널트킥으로 두 골을 내고 의기양양한 게임을 시작했고... ",
# "bloggername": "알짜정보가 가득한 유익한 블로그",
# "bloggerlink": "https://blog.naver.com/diva440",
# "postdate": "20210728"
#
# }
# ]
# }
#
# {
# "lastBuildDate": "Sat, 21 Aug 2021 16:16:19 +0900",
# "total": 3880910,
# "start": 71,
# "display": 10,
# "items": [
# {
# "title": "오늘의스코어 해외<b>축구</b>경기일정 챙기자, 라리가 이강인 소식!",
# "link": "https:\/\/blog.naver.com\/best03077?Redirect=Log&logNo=222458588531",
# "description": "오늘의스코어 해외<b>축구</b>경기일정 챙겨보자! 이제 라리가를 비롯해 해외<b>축구</b> 시즌이 보름 앞으로 다가왔습니다. 유럽<b>축구</b>는 시즌을 종료했지만 유로 대회와 올림픽 <b>축구</b>로 인해 그 어느 때보다 풍성한 볼거리가... ",
# "bloggername": "KBROS BLOG",
# "bloggerlink": "https://blog.naver.com/best03077",
# "postdate": "20210805"
#
# },
# {
# "title": "[9살 마음사전]승부욕있는 아이가 <b>축구</b>를 시작했을 때",
# "link": "https:\/\/blog.naver.com\/74440191?Redirect=Log&logNo=222469818911",
# "description": "엄마한테 얘기하면 그렇게 말할 줄 알았어.&quot; 승부욕있는 이 아이는 <b>축구</b>를 잘하고 싶어한다. 유치원에서 체육시간을 가장 싫어했던 아이가 유일하게 흥미를 보인 운동이다. <b>축구</b>에서 처음 졌을 때 억울해하며... ",
# "bloggername": "청춘누리와 함께하는 네모아트기획",
# "bloggerlink": "https://blog.naver.com/74440191",
# "postdate": "20210814"
#
# },
# {
# "title": "춘계 전국 유소년 <b>축구</b>대회 강구중학교",
# "link": "https:\/\/blog.naver.com\/tkfkdto?Redirect=Log&logNo=222443857780",
# "description": "춘계 전국 유소년 <b>축구</b>대회 춘계 전국 중등 <b>축구</b>대회가 영덕군 일원에서 열리고 있습니다. 정부 방역 지침에 따라서 대회가 열릴테니 학부형들도 보이지않고 선수들만 한두팀씩 보입니다. 도쿄 올림픽이... ",
# "bloggername": "코코네 일상",
# "bloggerlink": "https://blog.naver.com/tkfkdto",
# "postdate": "20210724"
#
# },
# {
# "title": "도쿄올림픽 <b>축구</b> 결승 브라질 스페인",
# "link": "https:\/\/blog.naver.com\/yes4500?Redirect=Log&logNo=222449360678",
# "description": "결승전 하이라이트 영상 도쿄올림픽 남자 <b>축구</b> 결승전 결과 금메달 : 브라질 은메달 : 스페인 동메달... 남자 <b>축구</b> 동메달 결정전에서 멕시코에 1-3으로 졌다. 4강전 결과 ●일본(0) : 스페인(1) 연장 후반 1... ",
# "bloggername": "브로찌",
# "bloggerlink": "https://blog.naver.com/yes4500",
# "postdate": "20210729"
#
# },
# {
# "title": "한국 대 뉴질랜드 <b>축구</b>가 불러온 가족톡",
# "link": "https:\/\/blog.naver.com\/yuagnes?Redirect=Log&logNo=222441266970",
# "description": "방금 한국 대 #뉴질랜드 <b>축구</b> 대표팀의 #올림픽 예선전이 끝났다. 다른 경기도 아닌 한국과 뉴질랜드의... 이번 뉴질랜드 <b>축구</b> 대표팀은 한국 <b>축구</b> 대표팀을 처음으로 이기는 이변(?)을 낳았다. 축알못인 내가... ",
# "bloggername": "별라 씨의 옴니암니 별난 소풍",
# "bloggerlink": "https://blog.naver.com/yuagnes",
# "postdate": "20210722"
#
# },
# {
# "title": "오버더피치_ 레알 <b>축구</b>져지 구매",
# "link": "https:\/\/blog.naver.com\/likeallthing?Redirect=Log&logNo=222474246787",
# "description": "02-2164-6144 서울 영등포구 경인로 846 1층 월화수목 10:30-20:00 금토일 10:30-20:30 <b>축구</b>, 그 이상의 문화를 만들어나가는 웹 매거진 <b>축구</b>져지를 정말 오랜만에 구매하게 됐습니다. 영등포 주민이다보니 오버더피치도... ",
# "bloggername": "스그난 숲",
# "bloggerlink": "https://blog.naver.com/likeallthing",
# "postdate": "20210818"
#
# },
# {
# "title": "2021 오룡기 전국 중등<b>축구</b> 대회 열전 돌입",
# "link": "https:\/\/blog.naver.com\/fastcheonan?Redirect=Log&logNo=222442105385",
# "description": "7월 26일부터 8월 6일까지 천안<b>축구</b>센터와 북부스포츠센터<b>축구</b>장에서 오령기 전국중등<b>축구</b>대회 개최 안녕하세요. 천안시입니다. 대한 <b>축구</b> 협회와 충남 <b>축구</b> 협회에서 주최한 '2021 오룡기 전국 중ㆍ등 <b>축구</b>... ",
# "bloggername": "새로운 천안 행복한 시민",
# "bloggerlink": "https://blog.naver.com/fastcheonan",
# "postdate": "20210723"
#
# },
# {
# "title": "대한민국 <b>축구</b> 대표팀, 멕시코전 역대 전적",
# "link": "https:\/\/blog.naver.com\/inzzang9807?Redirect=Log&logNo=222451821474",
# "description": "오늘 저녁 8시, 도쿄 올림픽 <b>축구</b> 4강 진출을 두고 격돌하게 될 멕시코. 월드컵에서의 멕시코와... 역대 전적 ■ 여자 U-17 대표팀 역대 전적 ■ 여자 유니버시아드 대표팀 역대 전적 □ 출처: 대한<b>축구</b>협회",
# "bloggername": "詩路(이런 날에는...)",
# "bloggerlink": "https://blog.naver.com/inzzang9807",
# "postdate": "20210731"
#
# },
# {
# "title": "도쿄 올림픽 <b>축구</b> 조편성 경기일정",
# "link": "https:\/\/blog.naver.com\/younalove2?Redirect=Log&logNo=222435245970",
# "description": "한국 도쿄올림픽 <b>축구</b> 일정 7월22일 오후 5시 뉴질랜드 vs 한국 (가시마스타디움) 7월 25일 오후 8시... 우승할 수 있을거라고 생각한다 #골키퍼의아쉬움#송범근아쉬움#송범근실수#<b>축구</b>일정#도쿄<b>축구</b>일정",
# "bloggername": "잔잔한 밤하늘",
# "bloggerlink": "https://blog.naver.com/younalove2",
# "postdate": "20210717"
#
# },
# {
# "title": "Geon’s 캐나다여름캠프⭐️Power soccer camp(<b>축구</b>캠... ",
# "link": "https:\/\/blog.naver.com\/km7899?Redirect=Log&logNo=222448156888",
# "description": "이번 여름방학에 건이는 스포츠맨의 일상을 살고 있어요 ㅋㅋ 운동을 좋아하는 친구라서 여름캠프 스케쥴을 짤 때 농구/<b>축구</b> 등의 캠프를 고르더라구요~ 7월 한달 원없이 운동을 한 것 같아요!! <b>축구</b>... ",
# "bloggername": "리오하우스♡캐나다,토론토,할리팩스, 유학&홈스테이",
# "bloggerlink": "https://blog.naver.com/km7899",
# "postdate": "20210728"
#
# }
# ]
# }
#
# {
# "lastBuildDate": "Sat, 21 Aug 2021 16:16:19 +0900",
# "total": 3880910,
# "start": 81,
# "display": 10,
# "items": [
# {
# "title": "'감동의 올림픽' 끝나고 '감동의 해외<b>축구</b>' 시작했다~",
# "link": "https:\/\/blog.naver.com\/kjsmk721?Redirect=Log&logNo=222470216913",
# "description": "지난 2주간 전 세계인들의 감동을 안겨준 올림픽이 끝나고, 또다시 감동을 안겨줄 해외<b>축구</b> 시즌이 열렸고 첫 경기부터 그 감동이 시작됐다! 해외 <b>축구</b>에 빠진지 어느덧 3년째, 그중에서도 내 사랑 영국의... ",
# "bloggername": "No Music No Life",
# "bloggerlink": "https://blog.naver.com/kjsmk721",
# "postdate": "20210814"
#
# },
# {
# "title": "인천<b>축구</b>의 역사를 인천시립박물관으로...",
# "link": "https:\/\/blog.naver.com\/sonpd1985?Redirect=Log&logNo=222420173997",
# "description": "선수의 <b>축구</b>화가 기증실에 전시되었습니다. 지난해에 29명의 기증자가 704점의 유물을 기증했다고... 이번에 전시되지 못한 기증품들은 앞으로 인천<b>축구</b>나 체육에 대한 기획전시회에서 만날 수 있도록... ",
# "bloggername": "CD굽는 사내",
# "bloggerlink": "https://blog.naver.com/sonpd1985",
# "postdate": "20210704"
#
# },
# {
# "title": "제52회 부산MBC 전국 고등학교 <b>축구</b>대회(20일 경기 결과)",
# "link": "https:\/\/blog.naver.com\/sksist?Redirect=Log&logNo=222471680979",
# "description": "제52회 부산MBC 전국 고등학교 <b>축구</b>대회가 8월 16일부터 29일까지 경상남도 양산시에서 실시됩니다. 대한<b>축구</b>협회와 부산MBC가 주최하고 부산광역시<b>축구</b>협회가 주관하는 본 대회는 총 48개팀이 참가해 12개... ",
# "bloggername": "MST 트레이닝센터",
# "bloggerlink": "https://blog.naver.com/sksist",
# "postdate": "20210815"
#
# },
# {
# "title": "제57회 추계 대학 <b>축구</b> 연맹전(22강 대진 - 22일 경기)",
# "link": "https:\/\/blog.naver.com\/sksist?Redirect=Log&logNo=222470426777",
# "description": "제57회 추계 대학 <b>축구</b> 연맹전이 8월 15일부터 31일까지 강원도 태백시에서 실시됩니다. 한국대학<b>축구</b>연맹이 주최하고 태백시<b>축구</b>협회가 주관하는 본 대회는 총 81개팀이 참가해 2개 그룹으로 나누어 그룹별... ",
# "bloggername": "MST 트레이닝센터",
# "bloggerlink": "https://blog.naver.com/sksist",
# "postdate": "20210814"
#
# },
# {
# "title": "너무 더운 문수양궁장 야간<b>축구</b>",
# "link": "https:\/\/blog.naver.com\/napalclinic?Redirect=Log&logNo=222464894489",
# "description": "오늘 화요일은 문수양궁장에서 <b>축구</b>하는 날입니다. 운치가 있는 문수양궁장입니다. 걷기에는 좋은... 이제는 건강을 위해 <b>축구</b>를 하는 나이지요. 옆구장에서도 열심히 경기를 하고 있습니다. 옆구장 팀은 젊은... ",
# "bloggername": "나팔꽃한의원",
# "bloggerlink": "https://blog.naver.com/napalclinic",
# "postdate": "20210810"
#
# },
# {
# "title": "스페인  <b>축구</b> 유학",
# "link": "https:\/\/blog.naver.com\/sweety7511?Redirect=Log&logNo=222442678078",
# "description": "코로나이후 이번달 가장 바쁘게 일하며 보내고 있는 스페인누나 오늘 상담은 <b>축구</b> 유학... sweety7511 #유럽코로나 #스페인<b>축구</b>유학 #<b>축구</b>유학 #알함브라궁전 #알함브라궁전의추억 #보니따호스텔 #스페인누나... ",
# "bloggername": "밥 잘먹는 스페인 사는 누나",
# "bloggerlink": "https://blog.naver.com/sweety7511",
# "postdate": "20210723"
#
# },
# {
# "title": "실시간tv보기 도쿄올림픽 <b>축구</b> 다시보기 해보자",
# "link": "https:\/\/blog.naver.com\/woou0417?Redirect=Log&logNo=222465777520",
# "description": "도쿄올림픽 <b>축구</b> 다시보기를 찾아보시는 분들은 꼭 한번 이용해보시라고 말씀을 드리고싶을정도로... 도쿄올림픽 <b>축구</b> 다시보기 뿐만아니라 야구,배구,농구같은 다양한 종목들의 경기들도... ",
# "bloggername": "서로의 쉴곳이 되어 주길 :)",
# "bloggerlink": "https://blog.naver.com/woou0417",
# "postdate": "20210812"
#
# },
# {
# "title": "주관적으로 뽑은 최고의 한국<b>축구</b> 국가대표팀 나이키 유니폼... ",
# "link": "https:\/\/blog.naver.com\/winz1?Redirect=Log&logNo=222444960883",
# "description": "주관적으로 뽑은 최고의 한국<b>축구</b> 국가대표팀 나이키 유니폼은 1998년 프랑스월드컵 예선 유니폼이다.... 당시 대한<b>축구</b>협회의 호랑이 엠블럼이 탄생하기 전이라서 태극기 패치를 부착한 것도 특징이다. 그래서... ",
# "bloggername": "스포츠에픽",
# "bloggerlink": "https://blog.naver.com/winz1",
# "postdate": "20210725"
#
# },
# {
# "title": "2021 춘계 전국 고등학교 <b>축구</b>대회(20일 경기 결과)",
# "link": "https:\/\/blog.naver.com\/sksist?Redirect=Log&logNo=222471712649",
# "description": "2021 춘계 전국 고등학교 <b>축구</b>대회가 8월 16일부터 29일까지 경상남도 합천군에서 실시됩니다. 대한<b>축구</b>협회가 주최하고 경상남도<b>축구</b>협회가 주관하는 본 대회는 총 52개팀이 참가해 13개 조로 나누어 조별... ",
# "bloggername": "MST 트레이닝센터",
# "bloggerlink": "https://blog.naver.com/sksist",
# "postdate": "20210815"
#
# },
# {
# "title": "탁구 남자 단체, 요트 남자, 야구 남자, <b>축구</b> 남자 대표팀 선수",
# "link": "https:\/\/blog.naver.com\/mcstkorea?Redirect=Log&logNo=222467429713",
# "description": "<b>축구</b> 남자 강윤성, 권창훈, 김동현, 김재우, 김진규, 김진야, 박지수, 설영우, 송민규, 송범근, 안준수, 안찬기, 엄원상, 원두재, 이강인, 이동경, 이동준, 이상민, 이유현, 정승원, 정태욱, 황의조 선수! 최고의... ",
# "bloggername": "도란도란 문화놀이터",
# "bloggerlink": "https://blog.naver.com/mcstkorea",
# "postdate": "20210812"
#
# }
# ]
# }
# {
# "lastBuildDate": "Sat, 21 Aug 2021 16:16:20 +0900",
# "total": 3880910,
# "start": 91,
# "display": 10,
# "items": [
# {
# "title": "올림픽 <b>축구</b> 시청 준비 끝!! 골~~~~(6:0)",
# "link": "https:\/\/blog.naver.com\/twks1811?Redirect=Log&logNo=222448699027",
# "description": "광복 롯데에 사람들이 없네요 와인과 위스키 한 병 사들고 <b>축구</b>볼 준비합니다 사은품으로 받은 조립식... 않네요 <b>축구</b>가 조금 일찍 시작해 웬지 낮술 마시는 기분인데 이 또한 살면서 잠깐씩 즐기는 작은 행복이... ",
# "bloggername": "영도뉴타운블로그",
# "bloggerlink": "https://blog.naver.com/twks1811",
# "postdate": "20210728"
#
# },
# {
# "title": "2021 금강대기 유소년 <b>축구</b>대회",
# "link": "https:\/\/blog.naver.com\/sksist?Redirect=Log&logNo=222462668509",
# "description": "2021 금강대기 유소년 <b>축구</b>대회가 8월 8일부터 13일까지 강원도 횡성군에서 실시됩니다. 대한<b>축구</b>협회와 강원도민일보가 주최하고 강원도<b>축구</b>협회가 주관하는 본 대회는 31개팀이 참가해 예선과 본선 조별 풀... ",
# "bloggername": "MST 트레이닝센터",
# "bloggerlink": "https://blog.naver.com/sksist",
# "postdate": "20210809"
#
# },
# {
# "title": "[페파피그중국어복습] 9주 <b>축구</b>,세탁관련표현 ,<b>축구</b>놀이... ",
# "link": "https:\/\/blog.naver.com\/innee2000?Redirect=Log&logNo=222465790235",
# "description": "세탁,<b>축구</b>관련 표현이 27개문장이었는데 복습주간 열심히 암기해서 거의 암기했네요. 3일간 9개의... <b>축구</b>놀이때문에 공도샀든데  실내에서만 <b>축구</b>놀이했네요. 스크립트까지 잘했어~ 중국어집중기라고... ",
# "bloggername": "꿈을 설계하는곳.",
# "bloggerlink": "https://blog.naver.com/innee2000",
# "postdate": "20210811"
#
# },
# {
# "title": "2020 도쿄올림픽 <b>축구</b> 8강 : 대한민국 vs 멕시코",
# "link": "https:\/\/blog.naver.com\/sumr2002?Redirect=Log&logNo=222449810567",
# "description": "7월 31일 토요일 저녁 8시 2020 도쿄올림픽 남자 <b>축구</b> 8강 대한민국 vs 멕시코 2020 도쿄올림픽 <b>축구</b> 일정 온두라스를 6:0으로 꺾고 우리나라 <b>축구</b> 대표팀이 조 1위로 8강에 진출했습니다. 7월 31일 토요일 오후... ",
# "bloggername": "반짝반짝 다이어리",
# "bloggerlink": "https://blog.naver.com/sumr2002",
# "postdate": "20210729"
#
# },
# {
# "title": "우아하고 호쾌한 여자 <b>축구</b> - 김혼비",
# "link": "https:\/\/blog.naver.com\/99040244?Redirect=Log&logNo=222472005940",
# "description": "우아하고 호쾌한 여자 <b>축구</b> 저자 김혼비 출판 민음사 발매 2018.06.08. - 유머가득한 작가 김혼비의 존재를... 전 국가대표 <b>축구</b> 선수를 앞에 앉혀 놓고, <b>축구</b>에 대한 훈수를 두는 조기 <b>축구</b>회 아저씨 에피소드를... ",
# "bloggername": "마음을 위로하는 소리",
# "bloggerlink": "https://blog.naver.com/99040244",
# "postdate": "20210816"
#
# },
# {
# "title": "제43회 문화체육관광부장관배 전국 고등학교 <b>축구</b>대회(20일... ",
# "link": "https:\/\/blog.naver.com\/sksist?Redirect=Log&logNo=222471726981",
# "description": "제43회 문화체육관광부장관배 전국 고등학교 <b>축구</b>대회가 8월 16일부터 29일까지 경상남도 고성군에서 실시됩니다. 대한<b>축구</b>협회와 MBC경남이 주최하고 경상남도<b>축구</b>협회가 주관하는 본 대회는 총 49개팀이... ",
# "bloggername": "MST 트레이닝센터",
# "bloggerlink": "https://blog.naver.com/sksist",
# "postdate": "20210816"
#
# },
# {
# "title": "[도쿄 올림픽] 허물어진 수비, 허망하게 끝난 <b>축구</b> 대표팀 메달... ",
# "link": "https://gimpoman.tistory.com/4611",
# "description": "최고 인기 스포츠 야구는 미국과 조 1위 결정전을 <b>축구</b>는 멕시코와 8강전을 치렀다. 여자배구는 8강... 지상파의 선택은 야구와 <b>축구</b>였다. 여자배구는 한. 일전이라는 특별함에도 지상파 전파를 타지 못했다.... ",
# "bloggername": "지후니 매거진",
# "bloggerlink": "https://gimpoman.tistory.com/",
# "postdate": "20210801"
#
# },
# {
# "title": "한국 = 올림픽 <b>축구</b> 역사상 FIFA 랭킹 차이가 큰 나라에 패한 팀",
# "link": "https://kini.kr/2350?category=537719",
# "description": "국제<b>축구</b>연맹(FIFA) 랭킹 39위 한국은 22일 일본 이바라키 가시마 스타디움 에서 뉴질랜드(122위)와 2020 도쿄(東京) 올림픽 남자 <b>축구</b> 조별리그 B조 1차전을 치렀습니다. 그리고 후반 25분 크리스 우드 (30)에게... ",
# "bloggername": "kini's Sportugese",
# "bloggerlink": "https://kini.kr/",
# "postdate": "20210722"
#
# },
# {
# "title": "[도쿄 올림픽] 루마니아 전 대승, 벼랑 끝 탈출 <b>축구</b> 국가대표팀",
# "link": "https://gimpoman.tistory.com/4603",
# "description": "728x90 반응형 도쿄 올림픽에서 가장 큰 관심을 받는 종목 중 하나는 남자 <b>축구</b>다. 남자 <b>축구</b>는 2012년 런던 올림픽에서 사상 첫 동메달을 획득하며 새로운 역사를 썼다. 당시 대표팀은 개최국 영국과의 8강전에서... ",
# "bloggername": "지후니 매거진",
# "bloggerlink": "https://gimpoman.tistory.com/",
# "postdate": "20210726"
#
# },
# {
# "title": "화이팅!! 도쿄올림픽 <b>축구</b> 경기_ 이젠 루마니아, 온두라스다!",
# "link": "https:\/\/blog.naver.com\/spring0915?Redirect=Log&logNo=222443251870",
# "description": ":: 올림픽 <b>축구</b>, 1차전에서 졌다. :: 아쉽....ㅠ :: 그러나 우리에겐 아직 두 경기가 남았다! :: 경기도 응원도 건강하게! :: 이번엔, 이기자. 그래야 해..... 2020 도쿄올림픽 남자<b>축구</b> 조별리그 1차전 07.22(목)... ",
# "bloggername": "엄마여행작가 다이어리",
# "bloggerlink": "https://blog.naver.com/spring0915",
# "postdate": "20210724"
#
# }
# ]
# }

# %%
import re

def processString(txt):
    specialChars = "!#$%^&*()"
    for specialChar in specialChars:
        txt = txt.replace(specialChar, '')
        txt = txt.replace(',', ' ')
        txt = txt.replace('.', ' ')
        txt = txt.replace('"', ' ')
        txt = txt.replace('ღ', ' ')
        txt = txt.replace('​', ' ')
        txt = txt.replace('  ', ' ')
        txt = txt.replace('   ', ' ')
        txt = txt.replace('    ', ' ')
        txt = txt.replace('     ', ' ')
    return txt.strip()

def processText(txt):
    specialChars = "!#$%^&*()"
    for specialChar in specialChars:
        txt = txt.replace('  ', ' ')
        txt = txt.replace('   ', ' ')
        txt = txt.replace('    ', ' ')
        txt = txt.replace('     ', ' ')
    return txt.strip()

# 본문에 키워드 언급 갯수
def keyword_search(txt):
    
    if(txt.find(keyword[0]) != -1):
        a = txt.find(keyword[0])
        b = 1
        while txt[a+1:].find(keyword) != -1:
            a = txt[a+1:].find(keyword) + a + 1
            b+=1
        return b

    

# 키워드가 본문의 처음 100단어 안에 포함되는가
def keyword_in_100(txt):
    a = txt.find("양궁")
    if(a<=100):
        return True
    else:
        return False
    
def site_popularity(link):
    if(re.search("naver", link)):
        return 10
    elif(re.search("daum", link)):
        return 5
    elif(re.search("tistory", link)):
        return 3
    else:
        return 1

# %%
import json
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import quote
import requests
import numpy as np
import datetime
import pandas as pd

text1 = []
text_amount = []
keyword_mentioned = []
items = []
for result_ in result:
    items += json.loads(result_)['items']

data = np.array([])
#items = 블로그 배열 (items[0] = 첫번째 블로그)

print(f'블로그 개수 : {len(items)}')

for i in range(len(items)):
    site_score = 0
    text2 = ""
    response1 = requests.get(items[i]['link'])
    #print(items[i]['link'])
    
    # 포털 사이트의 인지도
    site_score = site_popularity(items[i]['link'])
    #print(site_score)
    #print("\n")
    
    soup = BeautifulSoup(response1.text)
    if not soup.find_all('iframe'):
        continue
    idx = str(soup.find_all('iframe').pop()).find('src')
    source = str(soup.find_all('iframe').pop())[idx+5:-11]
    source = source.replace('amp;', '')
    if source.find('PostView.naver') == -1:
        continue
    url = 'http://blog.naver.com' + source
    response1 = requests.get(url)
    soup = BeautifulSoup(response1.text)
    # 예외처리
    temp = soup.find_all("div", "se-main-container") + soup.find_all("div", id="postViewArea")
    if not temp:
        continue
    temp1 = BeautifulSoup(str(temp.pop()))
    text = temp1.text.replace('\n', ' ')
    text1.append([processString(text)])
    title = items[i]['title']

    # 포스트 날짜
    postdate = datetime.datetime.strptime(items[i]['postdate'], '%Y%m%d')
    pastday = (datetime.datetime.now() - postdate).days
    pastday = -1*pastday
    #댓글 갯수
    comtemp = str(soup.find_all('em', id='floating_bottom_commentCount'))
    commentNu = comtemp.replace('[<em id="floating_bottom_commentCount">','').replace('\n','').replace('\t','').replace('</em>]','')
  
 
    try:
        commentNum = int(commentNu)
    except:
        commentNum = 0
    
    
    # 키워드 언급 개수
    keyword_mentioned.append([keyword_search(text)])
    
    # 본문 분량
    text2 += processText(text)
    text_amount.append(len(text2))
  
    #print("본문 분량:", text_amount[i], "자")
    #print("키워드 언급 횟수:", keyword_mentioned[i], "번")
    #print("댓글 개수:", commentNum,"개") 
    #print("본문의 처음 100단어안에 포함되는가:", keyword_in_100(text))

    if type(keyword) != list:
        keyword_list = keyword.split()
    keyword_title = []
  
    for k in keyword_list:
        keyword_title += [k in title]
    #print(f"제목에 키워드 포함 여부 : {keyword_list} : {keyword_title}")
  
    link_num = len(temp1.find_all('div', class_="se-module se-module-oglink"))
    #print(f'링크 개수 : {link_num}')
    
    player_num= len(temp1.find_all('div', class_= 'se-component se-video se-l-default') + temp1.find_all('a', class_="se-link"))
    #print(f'동영상 개수 : {player_num}')
    
    img_num= len(temp1.find_all('img'))
    #print(f'이미지 개수 : {img_num}')

    label = 1000 - i
    
    if commentNum == None:
        commentNum = 0
        print("commentNum is None")
    if link_num == None:
        link_num = 0
        print("link_num is None")
    if player_num == None:
        player_num = 0
        print("player_num is None")
    if img_num == None:
        img_num = 0
        print("img_num is None")
    if pastday == None:
        pastday = 0
        print("pastday is None")
    if len(text2) == None:
        print("len(text2) is None")
        continue
    if keyword_search(text) == None:
        print("keyword_search(text) is None")
        continue
    if keyword_in_100(text) == None:
        print("keyword_in_100(text) is None")
        continue
    
    
    data = np.append(data, np.array([int(len(text2)), int(keyword_search(text)), int(commentNum), int(keyword_in_100(text)), int(link_num), int(player_num), int(img_num), int(pastday), int(label)]))

    #print(text1[i])
    #print("-----------------------------------------------------------------")

#columns = ['본문길이', '키워드 언급개수', '댓글개수', '처음 100단어', '링크개수', '동영상개수', '이미지 개수', '지난 날짜', 'label']

#data = data.reshape(-1, len(columns))

#df = pd.DataFrame(data, columns = columns)
#df.to_csv('data.csv')
#df.head()
# Out:
# 블로그 개수 : 100
# https://blog.naver.com/zamtangei?Redirect=Log&logNo=222470963066
# 10
#
#
# https://blog.naver.com/soccer_girl?Redirect=Log&logNo=222471365862
# 10
#
#
# https://blog.naver.com/winz1?Redirect=Log&logNo=222453400852
# 10
#
#
# https://blog.naver.com/ccead?Redirect=Log&logNo=222452950324
# 10
#
#
# https://blog.naver.com/hoiung8672?Redirect=Log&logNo=222398156585
# 10
#
#
# https://blog.naver.com/nongsae?Redirect=Log&logNo=222462938182
# 10
#
#
# https://blog.naver.com/dongi0508?Redirect=Log&logNo=222451030302
# 10
#
#
# https://blog.naver.com/iparkstory?Redirect=Log&logNo=222447158784
# 10
#
#
# https://blog.naver.com/wtp53?Redirect=Log&logNo=222441024737
# 10
#
#
# https://blog.naver.com/gounikorea?Redirect=Log&logNo=222421901117
# 10
#
#
# https://blog.naver.com/yhkim444?Redirect=Log&logNo=222460136050
# 10
#
#
# https://blog.naver.com/dydxodi333?Redirect=Log&logNo=222395070104
# 10
#
#
# https://blog.naver.com/kipoworld2?Redirect=Log&logNo=222454377663
# 10
#
#
# https://blog.naver.com/2322033?Redirect=Log&logNo=222465841326
# 10
#
#
# https://blog.naver.com/ivanz?Redirect=Log&logNo=222450477164
# 10
#
#
# https://blog.naver.com/qlskdhkfkt?Redirect=Log&logNo=222473246018
# 10
#
#
# https://blog.naver.com/dsjfh85?Redirect=Log&logNo=222477798264
# 10
#
#
# https://blog.naver.com/mr_mo_mo?Redirect=Log&logNo=222450273740
# 10
#
#
# https://blog.naver.com/bulja200?Redirect=Log&logNo=222454379094
# 10
#
#
# https://blog.naver.com/monnong?Redirect=Log&logNo=222423928746
# 10
#
#
# https://blog.naver.com/dony_zzang?Redirect=Log&logNo=222468601981
# 10
#
#
# https://blog.naver.com/sksist?Redirect=Log&logNo=222470455035
# 10
#
#
# https://blog.naver.com/welovebex?Redirect=Log&logNo=222423859267
# 10
#
#
# https://blog.naver.com/dlvmshtm13?Redirect=Log&logNo=222430222000
# 10
#
#
# https://blog.naver.com/hissong0677?Redirect=Log&logNo=222439753474
# 10
#
#
# https://blog.naver.com/hans427?Redirect=Log&logNo=222430345029
# 10
#
#
# https://blog.naver.com/red_thwjd?Redirect=Log&logNo=222427331397
# 10
#
#
# https://blog.naver.com/peterfine?Redirect=Log&logNo=222451174675
# 10
#
#
# https://blog.naver.com/spotv_sports?Redirect=Log&logNo=222466996733
# 10
#
#
# https://blog.naver.com/kofmia?Redirect=Log&logNo=222414051286
# 10
#
#
# https://blog.naver.com/gunsanpr?Redirect=Log&logNo=222441263706
# 10
#
#
# https://blog.naver.com/dydxodi333?Redirect=Log&logNo=222448350755
# 10
#
#
# https://blog.naver.com/mr_mo_mo?Redirect=Log&logNo=222441074724
# 10
#
#
# https://blog.naver.com/qlskdhkfk2228?Redirect=Log&logNo=222442266492
# 10
#
#
# https://blog.naver.com/chesungmin?Redirect=Log&logNo=222400396664
# 10
#
#
# https://blog.naver.com/mark_420?Redirect=Log&logNo=222446332344
# 10
#
#
# https://blog.naver.com/doek11?Redirect=Log&logNo=222459458367
# 10
#
#
# https://blog.naver.com/ha_tak?Redirect=Log&logNo=222473065742
# 10
#
#
# https://blog.naver.com/yes4500?Redirect=Log&logNo=222415258589
# 10
#
#
# https://blog.naver.com/hackersingang?Redirect=Log&logNo=222473632525
# 10
#
#
# https://blog.naver.com/wjdgml4188?Redirect=Log&logNo=222451297821
# 10
#
#
# https://blog.naver.com/spring0915?Redirect=Log&logNo=222450423832
# 10
#
#
# https://blog.naver.com/rlaxodhkswkd?Redirect=Log&logNo=222437020213
# 10
#
#
# https://blog.naver.com/tentama?Redirect=Log&logNo=222460960946
# 10
#
#
# https://blog.naver.com/peace_2000?Redirect=Log&logNo=222476148769
# 10
#
#
# https://blog.naver.com/mr_mo_mo?Redirect=Log&logNo=222454833238
# 10
#
#
# https://blog.naver.com/ksn1665?Redirect=Log&logNo=222449762286
# 10
#
#
# https://blog.naver.com/yousy1009?Redirect=Log&logNo=222454486461
# 10
#
#
# https://blog.naver.com/yonghwi1?Redirect=Log&logNo=222470022517
# 10
#
#
# https://blog.naver.com/kkjkkj2000?Redirect=Log&logNo=222412803425
# 10
#
#
# https://blog.naver.com/hurkle97?Redirect=Log&logNo=222466488680
# 10
#
#
# https://blog.naver.com/banaly?Redirect=Log&logNo=222432573406
# 10
#
#
# https://blog.naver.com/byleekim2?Redirect=Log&logNo=222416703587
# 10
#
#
# https://blog.naver.com/cos2x?Redirect=Log&logNo=222442016283
# 10
#
#
# https://blog.naver.com/pinktao?Redirect=Log&logNo=222467648130
# 10
#
#
# https://blog.naver.com/iamprotein?Redirect=Log&logNo=222448388579
# 10
#
#
# https://blog.naver.com/hapymee?Redirect=Log&logNo=222449307180
# 10
#
#
# https://blog.naver.com/cjcityblog?Redirect=Log&logNo=222416180825
# 10
#
#
# https://blog.naver.com/mr_mo_mo?Redirect=Log&logNo=222460644736
# 10
#
#
# https://blog.naver.com/entercode?Redirect=Log&logNo=222468137641
# 10
#
#
# https://blog.naver.com/astralberry?Redirect=Log&logNo=222436569972
# 10
#
#
# https://blog.naver.com/lovelymooong?Redirect=Log&logNo=222452626769
# 10
#
#
# https://blog.naver.com/minumworld?Redirect=Log&logNo=222445938187
# 10
#
#
# https://blog.naver.com/kingeyes79?Redirect=Log&logNo=222449642339
# 10
#
#
# https://blog.naver.com/champ76?Redirect=Log&logNo=222452735655
# 10
#
#
# https://blog.naver.com/rlfem1wls?Redirect=Log&logNo=222410622307
# 10
#
#
# https://blog.naver.com/fastcheonan?Redirect=Log&logNo=222431155290
# 10
#
#
# https://blog.naver.com/gmlwn2149?Redirect=Log&logNo=222464311241
# 10
#
#
# https://blog.naver.com/winz1?Redirect=Log&logNo=222458286614
# 10
#
#
# https://blog.naver.com/diva440?Redirect=Log&logNo=222449090425
# 10
#
#
# https://blog.naver.com/best03077?Redirect=Log&logNo=222458588531
# 10
#
#
# https://blog.naver.com/74440191?Redirect=Log&logNo=222469818911
# 10
#
#
# https://blog.naver.com/tkfkdto?Redirect=Log&logNo=222443857780
# 10
#
#
# https://blog.naver.com/yes4500?Redirect=Log&logNo=222449360678
# 10
#
#
# https://blog.naver.com/yuagnes?Redirect=Log&logNo=222441266970
# 10
#
#
# https://blog.naver.com/likeallthing?Redirect=Log&logNo=222474246787
# 10
#
#
# https://blog.naver.com/fastcheonan?Redirect=Log&logNo=222442105385
# 10
#
#
# https://blog.naver.com/inzzang9807?Redirect=Log&logNo=222451821474
# 10
#
#
# https://blog.naver.com/younalove2?Redirect=Log&logNo=222435245970
# 10
#
#
# https://blog.naver.com/km7899?Redirect=Log&logNo=222448156888
# 10
#
#
# https://blog.naver.com/kjsmk721?Redirect=Log&logNo=222470216913
# 10
#
#
# https://blog.naver.com/sonpd1985?Redirect=Log&logNo=222420173997
# 10
#
#
# https://blog.naver.com/sksist?Redirect=Log&logNo=222471680979
# 10
#
#
# https://blog.naver.com/sksist?Redirect=Log&logNo=222470426777
# 10
#
#
# https://blog.naver.com/napalclinic?Redirect=Log&logNo=222464894489
# 10
#
#
# https://blog.naver.com/sweety7511?Redirect=Log&logNo=222442678078
# 10
#
#
# https://blog.naver.com/woou0417?Redirect=Log&logNo=222465777520
# 10
#
#
# https://blog.naver.com/winz1?Redirect=Log&logNo=222444960883
# 10
#
#
# https://blog.naver.com/sksist?Redirect=Log&logNo=222471712649
# 10
#
#
# https://blog.naver.com/mcstkorea?Redirect=Log&logNo=222467429713
# 10
#
#
# https://blog.naver.com/twks1811?Redirect=Log&logNo=222448699027
# 10
#
#
# https://blog.naver.com/sksist?Redirect=Log&logNo=222462668509
# 10
#
#
# https://blog.naver.com/innee2000?Redirect=Log&logNo=222465790235
# 10
#
#
# https://blog.naver.com/sumr2002?Redirect=Log&logNo=222449810567
# 10
#
#
# https://blog.naver.com/99040244?Redirect=Log&logNo=222472005940
# 10
#
#
# https://blog.naver.com/sksist?Redirect=Log&logNo=222471726981
# 10
#
#
# https://gimpoman.tistory.com/4611
# 3
#
#
# https://kini.kr/2350?category=537719
# 1
#
#
# https://gimpoman.tistory.com/4603
# 3
#
#
# https://blog.naver.com/spring0915?Redirect=Log&logNo=222443251870
# 10

# %%
from PyKomoran import Komoran, DEFAULT_MODEL
import konlpy
from konlpy.tag import *

hannanum = Hannanum()
kkma = Kkma()
okt = Okt()

#komoran = Komoran(DEFAULT_MODEL['LIGHT'])
#token_list = []
#for text in text1:
  #token_list += [hannanum.nouns(str(text1))]

#print(len(token_list))
#print(token_list[0])

# %%
import pandas as pd

df1 = pd.read_csv('C:/Users/tlsrl/data.csv')
df1
# Out:
#      Unnamed: 0    본문길이  키워드 언급개수   댓글개수  처음 100단어  링크개수  동영상개수  이미지 개수  \
# 0             0  2756.0       6.0  262.0       1.0   2.0    0.0    12.0
# 1             1  2616.0      23.0    4.0       1.0   0.0    0.0    14.0
# 2             2  2712.0       8.0    4.0       1.0   1.0    0.0     5.0
# 3             3  1404.0      12.0   17.0       1.0   0.0    0.0    17.0
# 4             4  3161.0      38.0   55.0       1.0   2.0    2.0    22.0
# ..          ...     ...       ...    ...       ...   ...    ...     ...
# 865         865  1425.0       6.0   10.0       1.0   0.0    0.0    29.0
# 866         866   917.0       6.0    0.0       1.0   0.0    0.0    14.0
# 867         867   667.0       5.0    3.0       1.0   0.0    0.0    36.0
# 868         868   579.0      12.0    1.0       1.0   1.0    0.0     7.0
# 869         869  1177.0       5.0    3.0       1.0   0.0    1.0    19.0
#
#      지난 날짜   label
# 0    -21.0  1000.0
# 1    -25.0   999.0
# 2    -19.0   997.0
# 3     -7.0   996.0
# 4    -25.0   995.0
# ..     ...     ...
# 865 -913.0     5.0
# 866  -26.0     4.0
# 867 -808.0     3.0
# 868  -21.0     2.0
# 869 -909.0     1.0
#
# [870 rows x 10 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import matplotlib.pyplot as plt

x = df1[['본문길이', '키워드 언급개수', '댓글개수', '처음 100단어', '링크개수', '동영상개수', '이미지 개수', '지난 날짜']]
y = df1[['label']]

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.75, test_size=0.25)
 
mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_predict = mlr.predict(x_test)

plt.scatter(y_test, y_predict)
plt.xlim(0, 1000)
plt.ylim(0 ,1000)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %%
plt.scatter(df1[['이미지 개수']], df1[['label']])
plt.show()
# Out:
#   File "<ipython-input-7-72cbf794b6ed>", line 4
#     1. 데이터셋을 수정
#        ^
# SyntaxError: invalid syntax

# %%
re.search("tistory","https://gimpoman.tistory.com/4603")
# Out:
# <re.Match object; span=(17, 24), match='tistory'>

# %%
import os
import sys
import json
import urllib.request
from powernad.API import RelKwdStat

BASE_URL = 'https://api.naver.com'
API_KEY = '0100000000f5d7a1f681fe839856de3701d4becaa61a2dead423467d4e8c429f1becb537ef'
SECRET_KEY = 'AQAAAAD116H2gf6DmFbeNwHUvsqml5vtAz8T6l/gYUM4Xn8mmg=='
CUSTOMER_ID = '2333431'

def naverKwdApi(keyword):
    
    rel_kwd_stat = RelKwdStat(BASE_URL, API_KEY, SECRET_KEY, CUSTOMER_ID)

    target_rel_kwd_stat = rel_kwd_stat.get_relkwd_stat_list(None, hintKeywords=keyword, showDetail='1')
    print(target_rel_kwd_stat[0].monthlyAveMobileClkCnt)
    
naverKwdApi("양궁")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-00a79afd2d91> in <module>
#       3 import json
#       4 import urllib.request
# ----> 5 from powernad.API import RelKwdStat
#       6
#       7 BASE_URL = 'https://api.naver.com'
#
# ~\anaconda3\lib\site-packages\powernad\API\RelKwdStat.py in <module>
# ----> 1 from powernad.Connector.restapi import RestApi
#       2 from powernad.Object.RelKwdStat.RelKwdStatObject import RelKwdStatObject
#       3 from typing import List
#       4 RelKwdStatObjectList = List[RelKwdStatObject]
#       5
#
# ~\anaconda3\lib\site-packages\powernad\Connector\restapi.py in <module>
#       6 import json
#       7 import requests
# ----> 8 import jsonpickle
#       9
#      10
#
# ModuleNotFoundError: No module named 'jsonpickle'
